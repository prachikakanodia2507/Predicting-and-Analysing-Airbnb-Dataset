# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('reviews.csv')

# %%
data.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        3781  37776825  2015-07-10     36059247          Greg
# 1        3781  41842494  2015-08-09     10459388           Tai
# 2        3781  45282151  2015-09-01     12264652        Damien
# 3        3781  49022647  2015-09-30     41426327          Mike
# 4        3781  52503327  2015-10-30     15151513          Ivan
#
#                                             comments
# 0  The apartment was as advertised and Frank was ...
# 1  It was a pleasure to stay at Frank's place. Th...
# 2  The apartment description is entirely faithful...
# 3  Thoroughly enjoyed my time at Frank's home. Ha...
# 4  Great value for the money! This location has e...

# %%
data.drop(['reviewer_id', 'reviewer_name', 'comments'], axis=1, inplace=True)

# %%
data.rename({'id':'review_count'}, axis=1, inplace=True)
data.review_count = 1

# %%
print("The first dataset has {} rows and {} columns.".format(*data.shape))
print("It contains {} duplicates.".format(data.duplicated().sum()))
# Out:
# The first dataset has 126679 rows and 3 columns.
# It contains 1999 duplicates.

# %%
data.date = pd.to_datetime(data.date, format="%Y-%m-%d")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126679 entries, 0 to 126678
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   listing_id    126679 non-null  int64
#  1   review_count  126679 non-null  int64
#  2   date          126679 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 2.9 MB

# %%
data.tail(2)
# Out:
#         listing_id  review_count       date
# 126677    52653198             1 2021-10-12
# 126678    52653198             1 2021-10-18

# %%
from datetime import datetime
data=data.sort_values('date')

# %%
data
df_raw=data

# %%
data
# Out:
#         listing_id  review_count       date
# 21            5506             1 2009-03-21
# 22            5506             1 2009-05-01
# 130           6695             1 2009-08-06
# 131           6695             1 2009-08-23
# 23            5506             1 2009-09-14
# ...            ...           ...        ...
# 61055     15018607             1 2021-10-19
# 100278    28494167             1 2021-10-19
# 116169    42975758             1 2021-10-19
# 126444    51446014             1 2021-10-19
# 124813    49484066             1 2021-10-19
#
# [126679 rows x 3 columns]

# %%
count_2020_21=data[data["date"].isin(pd.date_range('2020-10-01', '2021-10-19'))]
count_2020_19=data[data["date"].isin(pd.date_range('2019-01-01', '2020-12-31'))]

# %%
count_2020_21.head(30)
# Out:
#         listing_id  review_count       date
# 96373     25933888             1 2020-10-01
# 115684    42065558             1 2020-10-01
# 107609    34149470             1 2020-10-01
# 28015      5769127             1 2020-10-01
# 38244      7513906             1 2020-10-01
# 4885        561769             1 2020-10-01
# 39921      7713815             1 2020-10-01
# 118143    45449241             1 2020-10-01
# 36739      7474044             1 2020-10-01
# 75475     18875553             1 2020-10-01
# 118142    45449241             1 2020-10-01
# 33911      6810723             1 2020-10-01
# 97090     26395595             1 2020-10-01
# 26280      5434353             1 2020-10-01
# 107069    33417746             1 2020-10-01
# 117635    45349044             1 2020-10-01
# 33064      6759004             1 2020-10-01
# 109814    36036766             1 2020-10-01
# 78717     19309434             1 2020-10-01
# 117636    45349044             1 2020-10-01
# 117637    45349044             1 2020-10-01
# 78350     19292171             1 2020-10-01
# 38773      7531700             1 2020-10-01
# 69007     17559493             1 2020-10-01
# 117638    45349044             1 2020-10-01
# 113600    40287437             1 2020-10-02
# 67926     17399127             1 2020-10-02
# 118673    45515569             1 2020-10-02
# 110148    36114933             1 2020-10-02
# 114613    41740613             1 2020-10-02

# %%
print("The dataset 2017/2018 has {} reviews and {} columns.".format(*count_2020_21.shape))
# Out:
# The dataset 2017/2018 has 25997 reviews and 3 columns.

# %%
count_2020_21 = count_2020_21.set_index('date').sort_index()

# %%
count_2020_21_monthly = count_2020_21.groupby([pd.Grouper(freq='M'), 'listing_id'])['review_count'].agg(reviews_per_month='count').reset_index()

# %%
count_2020_21_monthly.columns = ['date', 'listing_id', 'reviews_per_month']

# %%
count_2020_21_monthly.set_index('date', inplace=True)

# %%
count_2020_21_monthly.head(5)
# Out:
#             listing_id  reviews_per_month
# date
# 2020-10-31      197972                  2
# 2020-10-31      210097                  3
# 2020-10-31      257588                  2
# 2020-10-31      561769                  1
# 2020-10-31      743211                  1

# %%
count_2020_21_monthly=count_2020_21_monthly.reset_index()
count_2020_21_monthly=pd.DataFrame(count_2020_21_monthly.groupby('listing_id')['reviews_per_month'].mean().reset_index())

# %%
count_2020_21_monthly.head(50)
# Out:
#     listing_id  reviews_per_month
# 0         3781           1.000000
# 1         5506           1.000000
# 2         6695           1.000000
# 3        10813           1.000000
# 4        29765           1.000000
# 5        40601           1.000000
# 6        45987           1.000000
# 7        60029           1.000000
# 8        67774           1.000000
# 9        77681           1.000000
# 10      163941           1.666667
# 11      182613           1.000000
# 12      190170           1.000000
# 13      197727           1.000000
# 14      197972           1.846154
# 15      210097           2.400000
# 16      220676           2.333333
# 17      257588           3.600000
# 18      447826           3.600000
# 19      533152           1.000000
# 20      561769           1.000000
# 21      568234           2.666667
# 22      601763           1.000000
# 23      611081           2.000000
# 24      743211           1.000000
# 25      750438           2.250000
# 26      766700           8.000000
# 27      815639          11.000000
# 28      863788           1.333333
# 29      891661           4.461538
# 30      894539           1.000000
# 31      916123           9.714286
# 32      989163           1.500000
# 33     1109224           1.000000
# 34     1275498           1.363636
# 35     1425973           1.000000
# 36     1445064           1.000000
# 37     1541166           1.000000
# 38     1544144           2.000000
# 39     1545185           3.000000
# 40     1596470           1.000000
# 41     1644031           5.714286
# 42     1682936           3.000000
# 43     1692573           3.000000
# 44     1724900           1.000000
# 45     1732804           1.500000
# 46     1810172           1.000000
# 47     1810397           1.000000
# 48     1881298           4.416667
# 49     2000797           1.333333

# %%
data_list=pd.read_csv("listings.csv")

# %%
data_list.tail(
)
# Out:
#             id                            listing_url       scrape_id  \
# 3244  52856176  https://www.airbnb.com/rooms/52856176  20211019170555
# 3245  52863673  https://www.airbnb.com/rooms/52863673  20211019170555
# 3246  52872248  https://www.airbnb.com/rooms/52872248  20211019170555
# 3247  52872801  https://www.airbnb.com/rooms/52872801  20211019170555
# 3248  52873214  https://www.airbnb.com/rooms/52873214  20211019170555
#
#      last_scraped                                       name  \
# 3244   2021-10-19  Bright 2 bed/2 bath condo with fireplace!
# 3245   2021-10-19     Cozy Studio Near MGH, Low Density Area
# 3246   2021-10-20        Furnished Room in Brighton Location
# 3247   2021-10-19        Furnished Room in Brighton Location
# 3248   2021-10-19         Furnished Room in Allston Location
#
#                                             description neighborhood_overview  \
# 3244  Enjoy a stay in Boston in the South Boston dis...                   NaN
# 3245  Corporate-style studio in the heart of Boston....                   NaN
# 3246  $200/MONTHLY FLEXIBILITY FEE<br />Unsure of ho...                   NaN
# 3247  $200/MONTHLY FLEXIBILITY FEE<br />Unsure of ho...                   NaN
# 3248  $200/MONTHLY FLEXIBILITY FEE<br />Unsure of ho...                   NaN
#
#                                             picture_url    host_id  \
# 3244  https://a0.muscache.com/pictures/miso/Hosting-...   22088530
# 3245  https://a0.muscache.com/pictures/4bbf0840-63c1...    2356643
# 3246  https://a0.muscache.com/pictures/fdf33796-03c3...  297860058
# 3247  https://a0.muscache.com/pictures/8a6a842a-3c52...  297860058
# 3248  https://a0.muscache.com/pictures/3e2db66a-b859...  297860058
#
#                                          host_url  ...  \
# 3244   https://www.airbnb.com/users/show/22088530  ...
# 3245    https://www.airbnb.com/users/show/2356643  ...
# 3246  https://www.airbnb.com/users/show/297860058  ...
# 3247  https://www.airbnb.com/users/show/297860058  ...
# 3248  https://www.airbnb.com/users/show/297860058  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 3244                         NaN                    NaN                 NaN
# 3245                         NaN                    NaN                 NaN
# 3246                         NaN                    NaN                 NaN
# 3247                         NaN                    NaN                 NaN
# 3248                         NaN                    NaN                 NaN
#
#          license instant_bookable calculated_host_listings_count  \
# 3244  STR-461030                t                              1
# 3245  STR-428031                f                             31
# 3246         NaN                f                            158
# 3247         NaN                f                            158
# 3248         NaN                f                            158
#
#      calculated_host_listings_count_entire_homes  \
# 3244                                           1
# 3245                                          12
# 3246                                           3
# 3247                                           3
# 3248                                           3
#
#      calculated_host_listings_count_private_rooms  \
# 3244                                            0
# 3245                                           19
# 3246                                          155
# 3247                                          155
# 3248                                          155
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 3244                                           0               NaN
# 3245                                           0               NaN
# 3246                                           0               NaN
# 3247                                           0               NaN
# 3248                                           0               NaN
#
# [5 rows x 74 columns]

# %%
data_list.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
data_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3249 entries, 0 to 3248
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3249 non-null   int64
#  1   listing_url                                   3249 non-null   object
#  2   scrape_id                                     3249 non-null   int64
#  3   last_scraped                                  3249 non-null   object
#  4   name                                          3249 non-null   object
#  5   description                                   3221 non-null   object
#  6   neighborhood_overview                         2136 non-null   object
#  7   picture_url                                   3249 non-null   object
#  8   host_id                                       3249 non-null   int64
#  9   host_url                                      3249 non-null   object
#  10  host_name                                     3249 non-null   object
#  11  host_since                                    3249 non-null   object
#  12  host_location                                 3248 non-null   object
#  13  host_about                                    2227 non-null   object
#  14  host_response_time                            2299 non-null   object
#  15  host_response_rate                            2299 non-null   object
#  16  host_acceptance_rate                          2375 non-null   object
#  17  host_is_superhost                             3249 non-null   object
#  18  host_thumbnail_url                            3249 non-null   object
#  19  host_picture_url                              3249 non-null   object
#  20  host_neighbourhood                            3057 non-null   object
#  21  host_listings_count                           3249 non-null   int64
#  22  host_total_listings_count                     3249 non-null   int64
#  23  host_verifications                            3249 non-null   object
#  24  host_has_profile_pic                          3249 non-null   object
#  25  host_identity_verified                        3249 non-null   object
#  26  neighbourhood                                 2136 non-null   object
#  27  neighbourhood_cleansed                        3249 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      3249 non-null   float64
#  30  longitude                                     3249 non-null   float64
#  31  property_type                                 3249 non-null   object
#  32  room_type                                     3249 non-null   object
#  33  accommodates                                  3249 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                3244 non-null   object
#  36  bedrooms                                      2798 non-null   float64
#  37  beds                                          3120 non-null   float64
#  38  amenities                                     3249 non-null   object
#  39  price                                         3249 non-null   object
#  40  minimum_nights                                3249 non-null   int64
#  41  maximum_nights                                3249 non-null   int64
#  42  minimum_minimum_nights                        3247 non-null   float64
#  43  maximum_minimum_nights                        3247 non-null   float64
#  44  minimum_maximum_nights                        3247 non-null   float64
#  45  maximum_maximum_nights                        3247 non-null   float64
#  46  minimum_nights_avg_ntm                        3247 non-null   float64
#  47  maximum_nights_avg_ntm                        3247 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              3249 non-null   object
#  50  availability_30                               3249 non-null   int64
#  51  availability_60                               3249 non-null   int64
#  52  availability_90                               3249 non-null   int64
#  53  availability_365                              3249 non-null   int64
#  54  calendar_last_scraped                         3249 non-null   object
#  55  number_of_reviews                             3249 non-null   int64
#  56  number_of_reviews_ltm                         3249 non-null   int64
#  57  number_of_reviews_l30d                        3249 non-null   int64
#  58  first_review                                  2334 non-null   object
#  59  last_review                                   2334 non-null   object
#  60  review_scores_rating                          2334 non-null   float64
#  61  review_scores_accuracy                        2321 non-null   float64
#  62  review_scores_cleanliness                     2322 non-null   float64
#  63  review_scores_checkin                         2320 non-null   float64
#  64  review_scores_communication                   2322 non-null   float64
#  65  review_scores_location                        2320 non-null   float64
#  66  review_scores_value                           2320 non-null   float64
#  67  license                                       1749 non-null   object
#  68  instant_bookable                              3249 non-null   object
#  69  calculated_host_listings_count                3249 non-null   int64
#  70  calculated_host_listings_count_entire_homes   3249 non-null   int64
#  71  calculated_host_listings_count_private_rooms  3249 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   3249 non-null   int64
#  73  reviews_per_month                             2334 non-null   float64
# dtypes: float64(21), int64(19), object(34)
# memory usage: 1.8+ MB

# %%
data_main=pd.merge(count_2020_21_monthly,data_list[['id', 'price', 'neighbourhood_group_cleansed', 
                          'latitude', 'longitude', 'property_type', 'accommodates', 
                          'bathrooms','room_type', 'bedrooms', 'beds', 'host_is_superhost','minimum_nights']], 
              left_on='listing_id', right_on='id')

# %%
data_main.drop(['id'], axis=1, inplace=True)

# %%
data_main.rename({'neighbourhood_group_cleansed':'neighbourhood'}, axis=1, inplace=True)

# %%
print("The dataset has {} rows and {} columns - after combining it.".format(*data_main.shape))
print("It contains {} duplicates.".format(data_main.duplicated().sum()))
data_main.head(50)
# Out:
# The dataset has 1574 rows and 14 columns - after combining it.
# It contains 0 duplicates.
#     listing_id  reviews_per_month    price  neighbourhood  latitude  \
# 0         3781           1.000000  $125.00            NaN  42.36413
# 1         5506           1.000000  $124.00            NaN  42.32844
# 2         6695           1.000000  $164.00            NaN  42.32802
# 3        10813           1.000000  $116.00            NaN  42.35061
# 4        29765           1.000000  $230.00            NaN  42.37754
# 5        40601           1.000000  $100.00            NaN  42.31347
# 6        45987           1.000000  $125.00            NaN  42.37424
# 7        60029           1.000000   $80.00            NaN  42.32546
# 8        67774           1.000000   $90.00            NaN  42.35689
# 9        77681           1.000000  $140.00            NaN  42.37865
# 10      163941           1.666667  $218.00            NaN  42.32806
# 11      182613           1.000000  $199.00            NaN  42.37739
# 12      190170           1.000000   $49.00            NaN  42.30953
# 13      197727           1.000000   $60.00            NaN  42.31331
# 14      197972           1.846154  $140.00            NaN  42.31533
# 15      210097           2.400000  $102.00            NaN  42.31685
# 16      220676           2.333333  $151.00            NaN  42.36614
# 17      257588           3.600000  $243.00            NaN  42.33255
# 18      447826           3.600000   $71.00            NaN  42.31658
# 19      533152           1.000000  $101.00            NaN  42.32212
# 20      561769           1.000000  $101.00            NaN  42.31371
# 21      568234           2.666667  $121.00            NaN  42.30360
# 22      601763           1.000000  $103.00            NaN  42.29192
# 23      611081           2.000000  $269.00            NaN  42.37579
# 24      743211           1.000000  $571.00            NaN  42.30702
# 25      750438           2.250000   $70.00            NaN  42.30733
# 26      766700           8.000000  $240.00            NaN  42.36570
# 27      815639          11.000000  $217.00            NaN  42.36695
# 28      863788           1.333333  $425.00            NaN  42.34510
# 29      891661           4.461538  $125.00            NaN  42.36650
# 30      894539           1.000000   $90.00            NaN  42.29017
# 31      916123           9.714286  $233.00            NaN  42.36541
# 32      989163           1.500000  $216.00            NaN  42.34308
# 33     1109224           1.000000  $448.00            NaN  42.32031
# 34     1275498           1.363636  $226.00            NaN  42.34294
# 35     1425973           1.000000  $350.00            NaN  42.34164
# 36     1445064           1.000000   $46.00            NaN  42.38017
# 37     1541166           1.000000  $118.00            NaN  42.38324
# 38     1544144           2.000000  $350.00            NaN  42.37243
# 39     1545185           3.000000  $141.00            NaN  42.34873
# 40     1596470           1.000000  $275.00            NaN  42.34988
# 41     1644031           5.714286  $100.00            NaN  42.33835
# 42     1682936           3.000000  $120.00            NaN  42.32382
# 43     1692573           3.000000  $145.00            NaN  42.31293
# 44     1724900           1.000000  $160.00            NaN  42.28447
# 45     1732804           1.500000   $65.00            NaN  42.29009
# 46     1810172           1.000000   $69.00            NaN  42.28127
# 47     1810397           1.000000  $890.00            NaN  42.34279
# 48     1881298           4.416667  $148.00            NaN  42.29867
# 49     2000797           1.333333   $95.00            NaN  42.31465
#
#     longitude                      property_type  accommodates  bathrooms  \
# 0   -71.02991                 Entire rental unit             2        NaN
# 1   -71.09581                 Entire guest suite             2        NaN
# 2   -71.09387         Entire condominium (condo)             4        NaN
# 3   -71.08787                 Entire rental unit             3        NaN
# 4   -71.06642                 Entire rental unit             2        NaN
# 5   -71.11082   Private room in residential home             2        NaN
# 6   -71.06081                 Entire rental unit             3        NaN
# 7   -71.08894        Private room in rental unit             1        NaN
# 8   -71.06206         Entire condominium (condo)             3        NaN
# 9   -71.06373        Private room in rental unit             2        NaN
# 10  -71.09423         Entire condominium (condo)             6        NaN
# 11  -71.06199                 Entire rental unit             6        NaN
# 12  -71.07060                 Entire guest suite             4        NaN
# 13  -71.12061        Private room in rental unit             1        NaN
# 14  -71.11025                 Entire rental unit             2        NaN
# 15  -71.10867            Entire residential home             2        NaN
# 16  -71.05226          Private room in townhouse             3        NaN
# 17  -71.04125                 Entire rental unit             4        NaN
# 18  -71.11012   Private room in residential home             2        NaN
# 19  -71.06096                 Entire rental unit             5        NaN
# 20  -71.06126                 Entire rental unit             6        NaN
# 21  -71.10539   Private room in residential home             4        NaN
# 22  -71.15407                 Entire rental unit             6        NaN
# 23  -71.04981                               Boat             6        NaN
# 24  -71.11283            Entire residential home             8        NaN
# 25  -71.11129        Private room in rental unit             1        NaN
# 26  -71.05618         Entire condominium (condo)             3        NaN
# 27  -71.05601         Entire condominium (condo)             3        NaN
# 28  -71.07150         Entire condominium (condo)             5        NaN
# 29  -71.05296                 Entire rental unit             4        NaN
# 30  -71.13169  Private room in bed and breakfast             2        NaN
# 31  -71.05404         Entire condominium (condo)             2        NaN
# 32  -71.07316                 Entire rental unit             2        NaN
# 33  -71.11290                 Entire rental unit             8        NaN
# 34  -71.07304                 Entire rental unit             2        NaN
# 35  -71.07964   Private room in residential home             6        NaN
# 36  -71.06236        Private room in rental unit             1        NaN
# 37  -71.07852                 Entire rental unit             2        NaN
# 38  -71.06349                   Entire townhouse             4        NaN
# 39  -71.15693                 Entire guest suite             4        NaN
# 40  -71.06918                   Entire townhouse             7        NaN
# 41  -71.04720          Private room in townhouse             2        NaN
# 42  -71.09641                 Entire rental unit             4        NaN
# 43  -71.11527            Entire residential home             4        NaN
# 44  -71.13301            Entire residential home             5        NaN
# 45  -71.05762        Private room in rental unit             2        NaN
# 46  -71.13304   Private room in residential home             2        NaN
# 47  -71.07110                   Entire townhouse             8        NaN
# 48  -71.11310                 Entire rental unit             4        NaN
# 49  -71.06240   Private room in residential home             2        NaN
#
#           room_type  bedrooms  beds host_is_superhost  minimum_nights
# 0   Entire home/apt       1.0   0.0                 t              32
# 1   Entire home/apt       1.0   1.0                 t               3
# 2   Entire home/apt       NaN   0.0                 t               3
# 3   Entire home/apt       NaN   1.0                 t              29
# 4   Entire home/apt       1.0   1.0                 f               2
# 5      Private room       1.0   1.0                 t              10
# 6   Entire home/apt       1.0   0.0                 t              29
# 7      Private room       1.0   1.0                 f               7
# 8   Entire home/apt       1.0   1.0                 t              91
# 9      Private room       1.0   1.0                 f               2
# 10  Entire home/apt       2.0   3.0                 t               3
# 11  Entire home/apt       2.0   4.0                 f              91
# 12  Entire home/apt       2.0   2.0                 f               7
# 13     Private room       1.0   1.0                 t              30
# 14  Entire home/apt       1.0   1.0                 t               3
# 15  Entire home/apt       NaN   1.0                 t               3
# 16     Private room       1.0   1.0                 t               3
# 17  Entire home/apt       2.0   2.0                 t               2
# 18     Private room       1.0   1.0                 t               3
# 19  Entire home/apt       2.0   2.0                 f              30
# 20  Entire home/apt       3.0   7.0                 f              30
# 21     Private room       2.0   2.0                 f               1
# 22  Entire home/apt       3.0   5.0                 f              30
# 23  Entire home/apt       1.0   4.0                 t               2
# 24  Entire home/apt       4.0   5.0                 f              29
# 25     Private room       1.0   1.0                 f               2
# 26  Entire home/apt       1.0   2.0                 f               1
# 27  Entire home/apt       1.0   2.0                 f               1
# 28  Entire home/apt       2.0   2.0                 f               3
# 29  Entire home/apt       1.0   2.0                 t               2
# 30     Private room       1.0   1.0                 t              30
# 31  Entire home/apt       1.0   1.0                 f               1
# 32  Entire home/apt       NaN   1.0                 t               1
# 33  Entire home/apt       4.0   6.0                 f               2
# 34  Entire home/apt       NaN   1.0                 t               1
# 35     Private room       3.0   4.0                 f               2
# 36     Private room       1.0   1.0                 f              29
# 37  Entire home/apt       NaN   1.0                 f               2
# 38  Entire home/apt       2.0   2.0                 t               3
# 39  Entire home/apt       1.0   2.0                 t               1
# 40  Entire home/apt       3.0   3.0                 f              29
# 41     Private room       1.0   1.0                 f               1
# 42  Entire home/apt       1.0   2.0                 t              30
# 43  Entire home/apt       2.0   0.0                 t               2
# 44  Entire home/apt       2.0   2.0                 f              29
# 45     Private room       1.0   1.0                 t               1
# 46     Private room       1.0   1.0                 f              29
# 47  Entire home/apt       3.0   4.0                 f               4
# 48  Entire home/apt       1.0   1.0                 f               1
# 49     Private room       1.0   1.0                 t               2

# %%
data_main['minimum_nights'].mean()
# Out:
# 14.155019059720457

# %%
data_main['reviews_per_month'].mean()
# Out:
# 2.5574857515772367

# %%
data_main.price = data_main.price.str.replace('$', '').str.replace(',', '').astype(float).astype(int)
data_main.price.isna().sum()
# Out:
# 0

# %%
data_main['price'].describe()
# Out:
# count    1574.000000
# mean      199.809403
# std       163.862801
# min         0.000000
# 25%        98.250000
# 50%       159.000000
# 75%       246.000000
# max      2589.000000
# Name: price, dtype: float64

# %%
red_square = dict(markerfacecolor='r', markeredgecolor='r', marker='.')
data_main['price'].plot(kind='box', xlim=(0, 1000), vert=False, flierprops=red_square, figsize=(16,2));

# %% [markdown]
# 75% of data is 246 dollars .so lets remove extremly priced above 450

# %%
data_main.drop(data_main[data_main['price'] > 450].index, axis=0, inplace=True)
data_main['price'].describe()
# Out:
# count    1478.000000
# mean      170.205007
# std        98.409748
# min         0.000000
# 25%        95.000000
# 50%       150.000000
# 75%       222.500000
# max       450.000000
# Name: price, dtype: float64

# %% [markdown]
# Monthly Occupancy Rate = Average Length of Stay * (No. of reviews per Month / Review Rate)
# According to the latest Airbnb update, guests who booked stays in Boston in 2021 via Airbnb spent 4.5 nights here on average.
#
# Yearly Income = Monthly Occupancy Rate Price 12 Months

# %%
avg_length_of_stay=4.5


review_rate_modest=0.5

# %%
data_main['modest_occupancy'] = round(avg_length_of_stay * (data_main['reviews_per_month']/review_rate_modest), 2)

# %%
len(data_main[data_main['modest_occupancy'] > 100])
# Out:
# 11

# %%
data_main.drop(data_main[(data_main['modest_occupancy'] > 100)].index, axis=0, inplace=True)

# %%
data_main['modest_occupancy'].describe()
# Out:
# count    1467.000000
# mean       21.788071
# std        14.888132
# min         9.000000
# 25%         9.000000
# 50%        18.000000
# 75%        28.800000
# max        99.000000
# Name: modest_occupancy, dtype: float64

# %%
data_main['optimistic_occupancy'] = round(avg_length_of_stay * (data_main['reviews_per_month']/0.4), 2)

# %%
len(data_main[data_main['optimistic_occupancy'] > 100])
# Out:
# 9

# %%
data_main['optimistic_occupancy'].describe()
# Out:
# count    1467.000000
# mean       27.235085
# std        18.610108
# min        11.250000
# 25%        11.250000
# 50%        22.500000
# 75%        36.000000
# max       123.750000
# Name: optimistic_occupancy, dtype: float64

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(8,5))

sns.distplot(data_main['modest_occupancy'], kde=False, bins=20, color='dimgrey')
sns.distplot(data_main['optimistic_occupancy'], kde=False, bins=20, color='gold')

plt.title('\nAverage Occupancy Rate\n', fontweight='bold')
plt.legend(['Modest Estimate', 'Optimistic Estimate'])
plt.xlabel('\nMonthly Occupancy in %')
plt.ylabel('Proportion of Accommodations\n')

# draw and label a line with median value of modest estimate
plt.axvline(x=25, ymin=0, ymax=1, linewidth=1, linestyle=':', color='black')
plt.text(14.5, 165, 'Median (Modest Estimate)')

# draw and label a line with median value of optimistic estimate
plt.axvline(x=25, ymin=0, ymax=0.9, linewidth=1, linestyle='-', color='gold')
plt.text(28, 165, 'Median (Optimistic Estimate)', color='goldenrod');

# %%
data_main['modest_income'] = data_main['modest_occupancy'] * data_main['price'] * 12
data_main.modest_income.describe()
# Out:
# count      1467.000000
# mean      46162.677546
# std       44044.311074
# min           0.000000
# 25%       15390.000000
# 50%       32184.000000
# 75%       62839.200000
# max      399114.000000
# Name: modest_income, dtype: float64

# %%
data_main['optimistic_income'] = data_main['optimistic_occupancy'] * data_main['price'] * 12
data_main.optimistic_income.describe()
# Out:
# count      1467.000000
# mean      57703.472638
# std       55055.517236
# min           0.000000
# 25%       19243.200000
# 50%       40230.000000
# 75%       78549.000000
# max      498915.840000
# Name: optimistic_income, dtype: float64

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(8,5))

sns.distplot(data_main['modest_income'], kde=False, bins=100, color='dimgrey')
sns.distplot(data_main['optimistic_income'], kde=False, bins=100, color='crimson')

plt.title('\nAverage Yearly Income\n', fontweight='bold')
plt.legend(['Modest Estimate', 'Optimistic Estimate'])
plt.xlabel('\nYearly Income in €')
plt.xlim((0,100000))
plt.ylabel('Proportion of Accommodations\n')

# draw and label a line with median value of modest estimate
plt.axvline(x=8709, ymin=0, ymax=1, linewidth=1, linestyle=':', color='black')
plt.text(60, 65, 'Median (Modest Estimate)')

# draw and label a line with median value of optimistic estimate
plt.axvline(x=10886, ymin=0, ymax=0.9, linewidth=1, linestyle='-', color='firebrick')
plt.text(100, 55, 'Median (Optimistic Estimate)', color='firebrick');

# %% [markdown]
# # To examine if there's an underlying seasonality, let's split the dataset we loaded at the very beginning by year

# %%
df_raw.tail(100)
# Out:
#         listing_id  review_count       date
# 74601     18584891             1 2021-10-17
# 125321    50187850             1 2021-10-17
# 109322    35836205             1 2021-10-17
# 126381    51329497             1 2021-10-17
# 121751    48014985             1 2021-10-17
# ...            ...           ...        ...
# 61055     15018607             1 2021-10-19
# 100278    28494167             1 2021-10-19
# 116169    42975758             1 2021-10-19
# 126444    51446014             1 2021-10-19
# 124813    49484066             1 2021-10-19
#
# [100 rows x 3 columns]

# %%
pf=df_raw[df_raw["date"].isin(pd.date_range('2021-01-01', '2021-10-10'))]

count_2021=pf
count_2021 = count_2021.set_index('date').sort_index()

# %%
count_2021
# Out:
#             listing_id  review_count
# date
# 2021-01-01    36237250             1
# 2021-01-01    36237250             1
# 2021-01-01    45349148             1
# 2021-01-01    36237250             1
# 2021-01-01    36237250             1
# ...                ...           ...
# 2021-10-10    41283883             1
# 2021-10-10    14868157             1
# 2021-10-10    29664067             1
# 2021-10-10    48015728             1
# 2021-10-10    51944717             1
#
# [21415 rows x 2 columns]

# %%
count_2021 = df_raw[df_raw["date"].isin(pd.date_range('2021-01-01', '2021-10-19'))]
count_2020 = df_raw[df_raw["date"].isin(pd.date_range('2020-01-01', '2020-12-31'))]
count_2019 = df_raw[df_raw["date"].isin(pd.date_range('2019-01-01', '2019-12-31'))]
count_2018 = df_raw[df_raw["date"].isin(pd.date_range('2018-01-01', '2018-12-31'))]


# set the date as index and sort by index
count_2021 = count_2021.set_index('date').sort_index()
count_2020 = count_2020.set_index('date').sort_index()
count_2019 = count_2019.set_index('date').sort_index()
count_2018 = count_2018.set_index('date').sort_index()

# calculate reviews per month    
count_2021_monthly = count_2021.groupby([pd.Grouper(freq='M'), 'listing_id'])['review_count'].agg(review_count_21='count').reset_index()
count_2020_monthly = count_2020.groupby([pd.Grouper(freq='M'), 'listing_id'])['review_count'].agg(review_count_20='count').reset_index()
count_2019_monthly = count_2019.groupby([pd.Grouper(freq='M'), 'listing_id'])['review_count'].agg(review_count_19='count').reset_index()
count_2018_monthly = count_2018.groupby([pd.Grouper(freq='M'), 'listing_id'])['review_count'].agg(review_count_18='count').reset_index()

# flatten the multi-index
count_2021_monthly.columns = ['date', 'listing_id', 'reviews_per_month_21']
count_2020_monthly.columns = ['date', 'listing_id', 'reviews_per_month_20']
count_2019_monthly.columns = ['date', 'listing_id', 'reviews_per_month_19']
count_2018_monthly.columns = ['date', 'listing_id', 'reviews_per_month_18']

# set date as index
count_2021_monthly.set_index('date', inplace=True)
count_2020_monthly.set_index('date', inplace=True)
count_2019_monthly.set_index('date', inplace=True)
count_2018_monthly.set_index('date', inplace=True)

# %%
count_2021_monthly.describe()
# Out:
#          listing_id  reviews_per_month_21
# count  6.526000e+03           6526.000000
# mean   3.169487e+07              3.399173
# std    1.627635e+07              4.220133
# min    3.781000e+03              1.000000
# 25%    1.829056e+07              1.000000
# 50%    3.542588e+07              2.000000
# 75%    4.777525e+07              4.000000
# max    5.265320e+07            143.000000

# %%
sns.set(style="dark")
fig, axes = plt.subplots(4, 1, figsize=(12,10))

sub_1 = count_2021_monthly.groupby('date')['reviews_per_month_21'].mean()
sub_1.plot(ax=axes[0], color='midnightblue', style=':')
axes[0].set_title('2021', fontweight='bold')
axes[0].set_xlabel('') 

sub_2 = count_2020_monthly.groupby('date')['reviews_per_month_20'].mean()
sub_2.plot(ax=axes[1], color='grey', style=':')
axes[1].set_title('2020', fontweight='bold')
axes[1].set_xlabel('') 

sub_3 = count_2019_monthly.groupby('date')['reviews_per_month_19'].mean()
sub_3.plot(ax=axes[2], color='coral', style=':')
axes[2].set_title('2019', fontweight='bold')
axes[2].set_xlabel('') 

sub_4 = count_2018_monthly.groupby('date')['reviews_per_month_18'].mean()
sub_4.plot(ax=axes[3], color='forestgreen', style=':')
axes[3].set_title('2018', fontweight='bold')
axes[3].set_xlabel('') 



# adjust space between subplots and set a title
plt.subplots_adjust(hspace = 0.6)
plt.suptitle('\nAverage Reviews per Month for Boston\n', fontweight='bold')

# plot common y-label
fig.text(0.04, 0.5, 'Average Reviews per Month', fontweight='bold', va='center', rotation='vertical');

# %% [markdown]
# # from above dataset we can observe that october is the peak season
# may-september there is peak season and then

# %% [markdown]
# # 2019

# %%
count_2021 = data[data["date"].isin(pd.date_range('2019-01-01', '2021-10-19'))]

# %%
data2 = data[data["date"].isin(pd.date_range('2019-01-01', '2019-12-31'))]

# %%
season_19=pd.merge(data2,data_list[['id', 'price','property_type']], 
              left_on='listing_id', right_on='id')
season_19.drop(['review_count', 'id'], axis='columns', inplace=True)
season_19.price =season_19.price.str.replace('$', '').str.replace(',', '').astype(float).astype(int)
data_main.price.isna().sum()
# Out:
# 0

# %%
season_19_peak=season_19[season_19["date"].isin(pd.date_range('2019-05-01', '2019-6-30'))]
season_19_peak_2=season_19[season_19["date"].isin(pd.date_range('2019-09-01', '2019-10-31'))]
p1=season_19_peak_2['price'].mean()
p2=season_19_peak['price'].mean()
res1=(p1+p2)/2
season_19_off=season_19[season_19["date"].isin(pd.date_range('2019-11-01', '2019-12-31'))]
season_19_off
p3=season_19_off['price'].mean()
season_19_off2=season_19[season_19["date"].isin(pd.date_range('2019-01-01', '2019-02-28'))]
p4=season_19_off2['price'].mean()
res2=(p3+p4)/2
(res1-res2)/res1
# Out:
# -0.07492066986054177

# %%
data3 = data[data["date"].isin(pd.date_range('2018-01-01', '2018-12-31'))]

# %%
data3
# Out:
#        listing_id  review_count       date
# 69212    17559846             1 2018-01-01
# 17170     3343428             1 2018-01-01
# 83553    20913672             1 2018-01-01
# 77775    19199379             1 2018-01-01
# 65885    16447567             1 2018-01-01
# ...           ...           ...        ...
# 24899     4909590             1 2018-12-31
# 98500    27429577             1 2018-12-31
# 55368    13594886             1 2018-12-31
# 22826     4568116             1 2018-12-31
# 90574    23171291             1 2018-12-31
#
# [25445 rows x 3 columns]

# %%
season_18=pd.merge(data3,data_list[['id', 'price','neighbourhood_cleansed','property_type']], 
              left_on='listing_id', right_on='id')
season_18.drop(['review_count', 'id'], axis='columns', inplace=True)

# %%
season_18.price =season_18.price.str.replace('$', '').str.replace(',', '').astype(float).astype(int)
data_main.price.isna().sum()
# Out:
# 0

# %%
season_18
# Out:
#        listing_id       date  price neighbourhood_cleansed  \
# 0        17559846 2018-01-01    125              Chinatown
# 1        17559846 2018-01-13    125              Chinatown
# 2        17559846 2018-01-21    125              Chinatown
# 3        17559846 2018-02-05    125              Chinatown
# 4        17559846 2018-02-23    125              Chinatown
# ...           ...        ...    ...                    ...
# 25440    22902242 2018-12-17    230                 Fenway
# 25441    26778714 2018-12-21    237              South End
# 25442    29711943 2018-12-21     26               Mattapan
# 25443    28578655 2018-12-22     64              Hyde Park
# 25444    16898190 2018-12-24     42               Brighton
#
#                           property_type
# 0                    Entire rental unit
# 1                    Entire rental unit
# 2                    Entire rental unit
# 3                    Entire rental unit
# 4                    Entire rental unit
# ...                                 ...
# 25440                Entire rental unit
# 25441                Entire rental unit
# 25442  Private room in residential home
# 25443  Private room in residential home
# 25444  Private room in residential home
#
# [25445 rows x 5 columns]

# %%
tr=pd.DataFrame(data_list.groupby('neighbourhood_cleansed')['id'].nunique())

# %%
df=season_18.groupby(['neighbourhood_cleansed']).agg({ 
    # find the min, max, and sum of the price column
    'price': ['min', 'max', 'mean']}).reset_index()

# %%
df=season_18.groupby(['date','listing_id']).agg({ 
    # find the min, max, and sum of the price column
    'price': ['min', 'max', 'mean']}).reset_index()
df
# Out:
#             date listing_id price
#                               min  max mean
# 0     2018-01-01     526970   148  148  148
# 1     2018-01-01     891661   125  125  125
# 2     2018-01-01     916123   233  233  233
# 3     2018-01-01    1038465   136  136  136
# 4     2018-01-01    1071235    94   94   94
# ...          ...        ...   ...  ...  ...
# 25420 2018-12-31   27203329    95   95   95
# 25421 2018-12-31   27429577   123  123  123
# 25422 2018-12-31   27669626   150  150  150
# 25423 2018-12-31   29134558    60   60   60
# 25424 2018-12-31   30036357   249  249  249
#
# [25425 rows x 5 columns]

# %%
filtered_data = df[df['listing_id']==1071235]
filtered_data
# Out:
#             date listing_id price
#                               min max mean
# 4     2018-01-01    1071235    94  94   94
# 347   2018-01-11    1071235    94  94   94
# 442   2018-01-15    1071235    94  94   94
# 572   2018-01-21    1071235    94  94   94
# 865   2018-02-01    1071235    94  94   94
# ...          ...        ...   ...  ..  ...
# 20576 2018-10-18    1071235    94  94   94
# 21056 2018-10-22    1071235    94  94   94
# 21388 2018-10-25    1071235    94  94   94
# 22303 2018-11-04    1071235    94  94   94
# 24366 2018-12-04    1071235    94  94   94
#
# [63 rows x 5 columns]

# %%
df=season_19.groupby(['property_type']).agg({ 
    # find the min, max, and sum of the price column
    'price': ['min', 'max', 'mean']}).reset_index()
df
# Out:
#                           property_type price
#                                           min    max        mean
# 0                                  Boat   266    278  269.076923
# 1              Entire bed and breakfast   200    200  200.000000
# 2            Entire condominium (condo)    53    975  213.560606
# 3                    Entire guest suite    49    294  124.730201
# 4                     Entire guesthouse    99    404  164.655172
# 5                           Entire loft    79    425  216.951648
# 6                          Entire place   185    185  185.000000
# 7                    Entire rental unit    49   5000  221.514521
# 8               Entire residential home    80   2589  326.296474
# 9             Entire serviced apartment   139    469  289.060811
# 10                     Entire townhouse   157   1014  387.789593
# 11                            Houseboat   212    212  212.000000
# 12    Private room in bed and breakfast    50    285  135.584270
# 13             Private room in bungalow    44     66   57.918367
# 14  Private room in condominium (condo)    26    220   85.527668
# 15          Private room in guest suite    60    157   97.167442
# 16           Private room in guesthouse    50     50   50.000000
# 17                 Private room in loft    33    116   97.721805
# 18          Private room in rental unit    25    200   82.216338
# 19     Private room in residential home    26   1000   87.208152
# 20            Private room in townhouse    39    190  104.958840
# 21            Room in bed and breakfast    75     75   75.000000
# 22               Room in boutique hotel   119  10000  581.979021
# 23                        Room in hotel     0    431  168.083333
# 24           Shared room in rental unit   115    115  115.000000
# 25      Shared room in residential home    49    110   61.200000
# 26             Shared room in townhouse    27     27   27.000000
